# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
def urunler(ad, fiyat):
     with open("urunler.txt", "r+") as file:
        file.write(f"ad : {ad}", "fiyat: {fiyat}\n")
           

urunEkle("iphone 13 mini", 56789)
urunEkle("samsung s21", 65432)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       3      with open("urunler.txt", "r+") as file:
#       4         file.write(f"ad : {ad}", "fiyat: {fiyat}\n")
# ----> 7 urunEkle("iphone 13 mini", 56789)
#       8 urunEkle("samsung s21", 65432)
#
# Cell In[7], line 5, in urunEkle(ad, fiyat)
#       3 try:
#       4    with open("urunler.txt", "w", encoding="utf-8") as file:
# ----> 5        dosya.write(f"ad : {ad}, fiyat: {fiyat}/n")
#       7 except ValueError as hata:
#       8     print(f"hata oluştu.")
#
# NameError: name 'dosya' is not defined

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
 def kelimeDeğiştir(filePath, eskiKelime, yeniKelime):
   with open("filePath", "r+") as file:
    file.read()
    file.seek(0)
    file.write(yeniKelime)
    file.trunclate()
    yeniKelime = text.replace(eskiKelime, yeniKelime)
      
kelimeDeğiştir(f, "iphone", "huawei")
# Out:
#   Cell In[16], line 2
#     def kelimeDeğiştir(filePath, eskiKelime, yeniKelime):
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
# 3.Problemin Çözümünü Buraya Yazınız
class Vehicle:
    def __init__(self, renk, model,):
        self.modelİsmi = model
        self.renk = renk
class bus(Vehicle):
    def sensorYak():
        print("Sensörler açık")
bus1 = bus("audi", "siyah")
print()
veh1 = Vehicle("kırmızı", "reno")
veh1.modelİsmi
veh1.renk
# Out:
# 'kırmızı'
